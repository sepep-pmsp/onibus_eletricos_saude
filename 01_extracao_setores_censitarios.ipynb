# %% [markdown]
# ## Extração setores censitários

# %% [markdown]
# Nesse notebook é extraída do IBGE a malha de setores censitários do estado de São Paulo.

# %%
import geopandas as gpd
import requests
from io import BytesIO
import os
from config import data_folder
from utils.save_shp import save_shp

# %%
def download_setores_censitarios():

    file = os.path.join(data_folder, 'setores_censitarios.shp')

    if os.path.exists(file):
        print('Retornando arquivo salvo')
        return gpd.read_file(file)

    print('Carregando do IBGE')

    url = ('https://geoftp.ibge.gov.br/organizacao_do_territorio/malhas_territoriais/malhas_de_setores_censitarios__divisoes_intramunicipais/censo_2022/setores/shp/UF/SP_setores_CD2022.zip')

    with requests.get(url) as r:
        content = BytesIO(r.content)
        gdf_setores_censitarios = gpd.read_file(content)

    save_shp(gdf_setores_censitarios, 'setores_censitarios.shp')

    return gdf_setores_censitarios

# %%
download_setores_censitarios()
# Out:
# Carregando do IBGE
# Shapefile salvo em data\setores_censitarios.shp
#                CD_SETOR SITUACAO CD_SIT CD_TIPO  AREA_KM2 CD_REGIAO NM_REGIAO  \
# 0       350010505000001   Urbana      1       0  0.123824         3   Sudeste
# 1       350010505000002   Urbana      1       0  0.202614         3   Sudeste
# 2       350010505000003   Urbana      1       0  0.235048         3   Sudeste
# 3       350010505000004   Urbana      1       0  0.288468         3   Sudeste
# 4       350010505000005   Urbana      1       0  0.213724         3   Sudeste
# ...                 ...      ...    ...     ...       ...       ...       ...
# 103314  355030817000585   Urbana      1       0  0.001434         3   Sudeste
# 103315  355030842000495   Urbana      1       0  0.002344         3   Sudeste
# 103316  355030884000286   Urbana      1       0  0.005812         3   Sudeste
# 103317  355030896000286   Urbana      1       0  0.026317         3   Sudeste
# 103318  355540605000557   Urbana      3       0  0.053148         3   Sudeste
#
#        CD_UF      NM_UF   CD_MUN  ... NM_FCU CD_AGLOM NM_AGLOM CD_RGINT  \
# 0         35  São Paulo  3500105  ...   None     None     None     3505
# 1         35  São Paulo  3500105  ...   None     None     None     3505
# 2         35  São Paulo  3500105  ...   None     None     None     3505
# 3         35  São Paulo  3500105  ...   None     None     None     3505
# 4         35  São Paulo  3500105  ...   None     None     None     3505
# ...      ...        ...      ...  ...    ...      ...      ...      ...
# 103314    35  São Paulo  3550308  ...   None     None     None     3501
# 103315    35  São Paulo  3550308  ...   None     None     None     3501
# 103316    35  São Paulo  3550308  ...   None     None     None     3501
# 103317    35  São Paulo  3550308  ...   None     None     None     3501
# 103318    35  São Paulo  3555406  ...   None     None     None     3511
#
#                    NM_RGINT  CD_RGI                                   NM_RGI  \
# 0       Presidente Prudente  350019                     Adamantina - Lucélia
# 1       Presidente Prudente  350019                     Adamantina - Lucélia
# 2       Presidente Prudente  350019                     Adamantina - Lucélia
# 3       Presidente Prudente  350019                     Adamantina - Lucélia
# 4       Presidente Prudente  350019                     Adamantina - Lucélia
# ...                     ...     ...                                      ...
# 103314            São Paulo  350001                                São Paulo
# 103315            São Paulo  350001                                São Paulo
# 103316            São Paulo  350001                                São Paulo
# 103317            São Paulo  350001                                São Paulo
# 103318  São José dos Campos  350051  Caraguatatuba - Ubatuba - São Sebastião
#
#        CD_CONCURB                                  NM_CONCURB  \
# 0            None                                        None
# 1            None                                        None
# 2            None                                        None
# 3            None                                        None
# 4            None                                        None
# ...           ...                                         ...
# 103314    3550308                                São Paulo/SP
# 103315    3550308                                São Paulo/SP
# 103316    3550308                                São Paulo/SP
# 103317    3550308                                São Paulo/SP
# 103318    3510500  Caraguatatuba - Ubatuba - São Sebastião/SP
#
#                                                  geometry
# 0       POLYGON ((-51.07255 -21.68865, -51.07237 -21.6...
# 1       POLYGON ((-51.07378 -21.6862, -51.07388 -21.68...
# 2       POLYGON ((-51.07138 -21.68313, -51.06965 -21.6...
# 3       POLYGON ((-51.0688 -21.68808, -51.0673 -21.690...
# 4       POLYGON ((-51.06969 -21.69442, -51.06928 -21.6...
# ...                                                   ...
# 103314  POLYGON ((-46.77357 -23.65136, -46.77337 -23.6...
# 103315  POLYGON ((-46.71384 -23.45128, -46.71384 -23.4...
# 103316  POLYGON ((-46.41717 -23.50021, -46.4172 -23.50...
# 103317  POLYGON ((-46.41079 -23.53101, -46.41089 -23.5...
# 103318  POLYGON ((-45.17718 -23.48706, -45.17691 -23.4...
#
# [103319 rows x 30 columns]
