# %% [markdown]
# ## Tratamento setores censitários

# %% [markdown]
# Nesse notebook é tratada a malha do IBGE de setores censitários do estado de São Paulo.

# %%
from utils.load_shp import load_shp
from utils.save_shp import save_shp

# %%
setores_censitarios = load_shp('setores_censitarios.shp')

# %% [markdown]
# Filtro para o município de São Paulo.

# %%
setores_censitarios_sp = setores_censitarios[setores_censitarios['CD_MUN'] == '3550308']

# %%
setores_censitarios_sp.head()
# Out:
#               CD_SETOR SITUACAO CD_SIT CD_TIPO  AREA_KM2 CD_REGIAO NM_REGIAO  \
# 66805  355030801000001   Urbana      1       0  0.071797         3   Sudeste
# 66806  355030801000002   Urbana      1       0  0.071902         3   Sudeste
# 66807  355030801000003   Urbana      1       0  0.055681         3   Sudeste
# 66808  355030801000004   Urbana      1       0  0.064905         3   Sudeste
# 66809  355030801000005   Urbana      1       0  0.086822         3   Sudeste
#
#       CD_UF      NM_UF   CD_MUN  ... NM_FCU CD_AGLOM NM_AGLOM CD_RGINT  \
# 66805    35  São Paulo  3550308  ...   None     None     None     3501
# 66806    35  São Paulo  3550308  ...   None     None     None     3501
# 66807    35  São Paulo  3550308  ...   None     None     None     3501
# 66808    35  São Paulo  3550308  ...   None     None     None     3501
# 66809    35  São Paulo  3550308  ...   None     None     None     3501
#
#         NM_RGINT  CD_RGI     NM_RGI CD_CONCURB    NM_CONCURB  \
# 66805  São Paulo  350001  São Paulo    3550308  São Paulo/SP
# 66806  São Paulo  350001  São Paulo    3550308  São Paulo/SP
# 66807  São Paulo  350001  São Paulo    3550308  São Paulo/SP
# 66808  São Paulo  350001  São Paulo    3550308  São Paulo/SP
# 66809  São Paulo  350001  São Paulo    3550308  São Paulo/SP
#
#                                                 geometry
# 66805  POLYGON ((-46.56954 -23.56918, -46.57016 -23.5...
# 66806  POLYGON ((-46.56806 -23.56521, -46.56786 -23.5...
# 66807  POLYGON ((-46.56619 -23.56605, -46.56632 -23.5...
# 66808  POLYGON ((-46.56876 -23.56856, -46.56863 -23.5...
# 66809  POLYGON ((-46.57121 -23.57005, -46.57056 -23.5...
#
# [5 rows x 30 columns]

# %%
setores_censitarios_sp['CD_MUN'].unique()
# Out:
# array(['3550308'], dtype=object)

# %%
save_shp(setores_censitarios_sp, 'setores_censitarios_sp.shp')
# Out:
# Shapefile salvo em data\setores_censitarios_sp.shp
